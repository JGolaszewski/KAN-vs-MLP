# %% [markdown]
# ## Necessary imports

# %%
import numpy as np

# %% [markdown]
# ## MLP Network(for reference)

# %%
# Prosta sieć neuronowa z jedną ukrytą warstwą do rozwiązania problemu XOR
# ReLU i jego pochodna
def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return (x > 0).astype(float)

# Sigmoid i jego pochodna (dla warstwy wyjściowej)
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    s = sigmoid(x)
    return s * (1 - s)

# Dane XOR
X = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [1],
              [1],
              [0]])

# Parametry
np.random.seed(1)
input_size = 2
hidden_size = 4
output_size = 1

# Inicjalizacja wag i biasów
W1 = np.random.randn(input_size, hidden_size) * 0.1
b1 = np.zeros((1, hidden_size))
W2 = np.random.randn(hidden_size, output_size) * 0.1
b2 = np.zeros((1, output_size))

# Hiperparametry
lr = 0.1
epochs = 10000

# Trening
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(X, W1) + b1 #dot product to iloczyn skalarny(do kombinacji liniowej)
    a1 = relu(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = sigmoid(z2)

    # Obliczanie błędu
    loss = np.mean((y - a2) ** 2)

    # Backward pass
    d_loss_a2 = 2 * (a2 - y)
    d_a2_z2 = sigmoid_derivative(z2)
    d_z2_W2 = a1

    d_W2 = np.dot(d_z2_W2.T, d_loss_a2 * d_a2_z2)
    d_b2 = np.sum(d_loss_a2 * d_a2_z2, axis=0, keepdims=True)

    d_z2_a1 = W2
    d_a1_z1 = relu_derivative(z1)
    d_z1_W1 = X

    d_W1 = np.dot(d_z1_W1.T, (np.dot(d_loss_a2 * d_a2_z2, d_z2_a1.T) * d_a1_z1))
    d_b1 = np.sum((np.dot(d_loss_a2 * d_a2_z2, d_z2_a1.T) * d_a1_z1), axis=0, keepdims=True)

    # Aktualizacja wag
    W2 -= lr * d_W2
    b2 -= lr * d_b2
    W1 -= lr * d_W1
    b1 -= lr * d_b1

    if epoch % 1000 == 0:
        print
        (f"Epoch {epoch}, Loss: {loss:.5f}")

# Wyniki
print("\nWynik po treningu:")
print("Wejście:\n", X)
print("Przewidywane:\n", a2.round(3))
# Out:
# Epoch 0, Loss: 0.24954
# Epoch 1000, Loss: 0.00246
# Epoch 2000, Loss: 0.00083
# Epoch 3000, Loss: 0.00048
# Epoch 4000, Loss: 0.00034
# Epoch 5000, Loss: 0.00026
# Epoch 6000, Loss: 0.00021
# Epoch 7000, Loss: 0.00017
# Epoch 8000, Loss: 0.00015
# Epoch 9000, Loss: 0.00013
#
# Wynik po treningu:
# Wejście:
#  [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# Przewidywane:
#  [[0.014]
#  [0.993]
#  [0.993]
#  [0.014]]

# %% [markdown]
# ## KAN Network
